# %%
import psycopg2
import pandas as pd

# Create a connection
conn = psycopg2.connect(
    host='db',  # Use the service name from Docker Compose as the hostname
    port=5432,
    dbname='tradedb',
    user='postgres',
    password='postgres'
)

# Create a cursor object
cur = conn.cursor()

# Execute a query
cur.execute("SELECT * FROM raw.trades")

# Fetch the results
rows = cur.fetchall()

# Get the column names from the cursor description
columns = [desc[0] for desc in cur.description]

# Create a DataFrame
df = pd.DataFrame(rows, columns=columns)
df2 = pd.DataFrame(rows, columns=columns)

# Create alias
raw_trades_df = df

# Adding a date column to the DataFrame
raw_trades_df['date'] = raw_trades_df['timestamp'].dt.date

# Create a new column 'prev_side' to store the previous side value for each account_id, symbol, and date
raw_trades_df['prev_side'] = raw_trades_df.sort_values(by='timestamp').groupby(['account_id', 'symbol', 'date'])['side'].shift()

# Filter rows where side is 'sell' and prev_side is 'buy'
buy_sell_pairs_df = raw_trades_df[(raw_trades_df['side'] == 'sell') & (raw_trades_df['prev_side'] == 'buy')]

# Group by account_id and count the number of pattern day trades
pdt_count_df = buy_sell_pairs_df.groupby('account_id').size().reset_index(name='pdt_count')

# Sort by pdt_count in descending order
pdt_count_df.sort_values(by='pdt_count', ascending=False, inplace=True)

pdt_count_df

# Write DataFrame to CSV
pdt_count_df.to_csv('pdt_count.csv', index=False)

# Close the cursor and connection
cur.close()
conn.close()

# %%
import psycopg2
import pandas as pd

# Create a connection
conn = psycopg2.connect(
    host='db',  # Use the service name from Docker Compose as the hostname
    port=5432,
    dbname='tradedb',
    user='postgres',
    password='postgres'
)

# Create a cursor object
cur = conn.cursor()

# Execute a query
cur.execute("SELECT * FROM raw.trades where account_id = '63132'")

# Fetch the results
rows = cur.fetchall()

# Get the column names from the cursor description
columns = [desc[0] for desc in cur.description]

# Create a DataFrame
df = pd.DataFrame(rows, columns=columns)

# Add a new column initialized to 0
df['new_column'] = 0

# Adding date column
df['date'] = df['timestamp'].dt.date

# Iterate over the DataFrame starting from the second row
for i in range(1, len(df)):
    # Check conditions
    if (df.loc[i, 'symbol'] == df.loc[i-1, 'symbol'] and
        df.loc[i, 'date'] == df.loc[i-1, 'date']):

        if df.loc[i-1, 'new_column'] == 1:
            df.loc[i, 'new_column'] = 0
        elif df.loc[i, 'side'] != df.loc[i-1, 'side']:
            df.loc[i, 'new_column'] = 1
        else:
            df.loc[i, 'new_column'] = 0
    else:
        df.loc[i, 'new_column'] = 0

# Sum of new_column for the account 63132
sum_new_column = df['new_column'].sum()

print(f"Sum of new_column for account 63132: {sum_new_column}")
# Out:
# Sum of new_column for account 63132: 7
